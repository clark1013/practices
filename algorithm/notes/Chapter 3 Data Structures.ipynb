# %%
https://ttsmaker.com/

# %% [markdown]
# # 3.10 Exercises

# %% [markdown]
# 3-1. A common problem for compilers and text editors is determining whether the parentheses are balanced and nested properly. For example, the string ((())())() contains properly nested pairs of parentheses, while the string )() and ()) do not. Give an algorithm that returns true if a string contains properly nested and balanced parentheses, and false if otherwise. For full credit, identity the position of first offending parenthesis if the string is not properly nested and balanced.

# %%
import IPython
IPython.display.Audio("audios/3-1.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
